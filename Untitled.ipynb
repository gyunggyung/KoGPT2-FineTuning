# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/lyrics_dataset_to_use.csv")
df
# Out:
#         Unnamed: 0  track number                              title  \
# 0                0      30041904                            Restart
# 1                1       2425159                            고장난 벽시계
# 2                2       3796043  Good Love (feat. Aubrey Peeples)
# 3                3      80011323                       Kiss Friends
# 4                4      31311677                      20살, 그 봄날의 기억
# ...            ...           ...                                ...
# 807602      807602       1617820                             눈물이 나요
# 807603      807603       3365064          Dj Got Us Fallin' In Love
# 807604      807604      80138965                           Any Love
# 807605      807605         81518                             그대와 함께
# 807606      807606      30441242                                Air
#
#                                                    lyrics  days_score  \
# 0       \r\r//\nI wanna restart to \r\r//\nfive years ...           0
# 1       \r\r//\n세월아 너는 어찌 돌아도 보지 않느냐\r\r//\n나를 속인 사람보다...           0
# 2       \r\r//\nOooh, you got a way of just knowing wh...           0
# 3       \r\r//\nyo this is click-B We are all is B \r\...           0
# 4       \r\r//\n나는 너를 보고 너는 나를 보며\r\r//\n내 손을 잡고선 저 별에...           0
# ...                                                   ...         ...
# 807602  \r\r//\n하루는 꿈에도 눈물이 나고\r\r//\n또 하룬 그대 이름 불러봅니다...           0
# 807603  \r\r//\n(yeah man) \r\r//\nSo we back in the c...           0
# 807604  \r\r//\nI speak to myself sometimes, and I say...           0
# 807605  \r\r//\n넌 그렇게 내게 다가왔었지 \r\r//\n내 마음속의 빈곳을 찾아 \...           0
# 807606  \r\r//\n이 무거운 공기 , 없어, 넌 없어\r\r//\n이겨낼수 없는, 중력...           0
#
#         weeks_score          genre           style                     artist  \
# 0                 0            NaN             NaN             플래너스(Planners)
# 1                 0            NaN             NaN                         진성
# 2                 0        팝, OST   컨트리 팝, TV 드라마     Nashville Cast(내쉬빌 캐스트)
# 3                 0            NaN             NaN                  제이엔씨(JNC)
# 4                 0      발라드/댄스/팝            댄스 팝                         김덕군
# ...             ...            ...             ...                        ...
# 807602            0            NaN             NaN                         유나
# 807603            0            NaN             NaN                  Usher(어셔)
# 807604            0            NaN             NaN   Luther Vandross(루더 반드로스)
# 807605            0            NaN             NaN                  페이스(Face)
# 807606            0  인디, 발라드/댄스/팝       발라드, 인디 팝   듀이필즈(Dewy-Fields), 진(Jin)
#
#                           agency composer distributor release_date lyricist  \
# 0                            NaN      NaN         NaN          NaN      NaN
# 1                            NaN      NaN         NaN          NaN      NaN
# 2       Big Machine Records, LLC      NaN   유니버설뮤직코리아          NaN      NaN
# 3                            NaN      NaN         NaN          NaN      NaN
# 4                            NaN      김덕군  루미넌트엔터테인먼트   2018.11.14      김덕군
# ...                          ...      ...         ...          ...      ...
# 807602                       NaN      NaN         NaN          NaN      NaN
# 807603                       NaN      NaN         NaN          NaN      NaN
# 807604                       NaN      NaN         NaN          NaN      NaN
# 807605                       NaN      NaN         NaN          NaN      NaN
# 807606                       NaN      NaN  보자기레이블앤미디어   2016.11.19      NaN
#
#              Featuring producer
# 0                  NaN      NaN
# 1                  NaN      NaN
# 2       Aubrey Peeples      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...                ...      ...
# 807602             NaN      NaN
# 807603             NaN      NaN
# 807604             NaN      NaN
# 807605             NaN      NaN
# 807606             NaN      NaN
#
# [807607 rows x 16 columns]

# %%
from torch.utils.data import Dataset
from kogpt2.utils import download, tokenizer, get_tokenizer
from gluonnlp.data import SentencepieceTokenizer
import gluonnlp
import numpy as np
# Out:
# C:\Users\hwnau\AppData\Roaming\Python\Python36\site-packages\mxnet\optimizer\optimizer.py:167: UserWarning: WARNING: New optimizer gluonnlp.optimizer.lamb.LAMB is overriding existing optimizer mxnet.optimizer.optimizer.LAMB
#   Optimizer.opt_registry[name].__name__))
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-3fefadfc9e5b> in <module>
#       1 from torch.utils.data import Dataset
# ----> 2 from kogpt2.utils import download, tokenizer, get_tokenizer
#       3 from gluonnlp.data import SentencepieceTokenizer
#       4 import gluonnlp
#       5 import numpy as np
#
# C:\github\KoGPT2-FineTuning\kogpt2\__init__.py in <module>
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
# ---> 15 from . import model
#      16
#      17 __version__ = '0.1.0'
#
# C:\github\KoGPT2-FineTuning\kogpt2\model\__init__.py in <module>
#      16
#      17 from .gpt import *
# ---> 18 from .torch_gpt2 import *
#
# C:\github\KoGPT2-FineTuning\kogpt2\model\torch_gpt2.py in <module>
#      26 from torch.nn.functional import gelu
#      27
# ---> 28 from transformers.configuration_gpt2 import GPT2Config
#      29 from transformers.file_utils import add_start_docstrings
#      30 from transformers.modeling_utils import Conv1D, PreTrainedModel, SequenceSummary, prune_conv1d_layer
#
# ~\.conda\envs\cuda\lib\site-packages\transformers\__init__.py in <module>
#      21
#      22 # Benchmarking
# ---> 23 from .benchmark_utils import (
#      24     Frame,
#      25     Memory,
#
# ~\.conda\envs\cuda\lib\site-packages\transformers\benchmark_utils.py in <module>
#      12 from typing import Iterable, List, NamedTuple, Optional, Union
#      13
# ---> 14 from .file_utils import is_tf_available, is_torch_available
#      15
#      16
#
# ~\.conda\envs\cuda\lib\site-packages\transformers\file_utils.py in <module>
#      25 from botocore.exceptions import ClientError
#      26 from filelock import FileLock
# ---> 27 from tqdm.auto import tqdm
#      28
#      29 from . import __version__
#
# ModuleNotFoundError: No module named 'tqdm.auto'

# %%
import tqdm

# %%
def sentencePieceTokenizer():
	tok_path = get_tokenizer()
	sentencepieceTokenizer = SentencepieceTokenizer(tok_path)
	return sentencepieceTokenizer


def koGPT2Vocab():
	cachedir = '~/kogpt2/'

	# download vocab
	vocab_info = tokenizer
	vocab_path = download(vocab_info['url'],
						vocab_info['fname'],
						vocab_info['chksum'],
						cachedir=cachedir)

	koGPT2_vocab = gluonnlp.vocab.BERTVocab.from_sentencepiece(vocab_path,
															 mask_token=None,
															 sep_token=None,
															 cls_token=None,
															 unknown_token='<unk>',
															 padding_token='<pad>',
															 bos_token='<s>',
															 eos_token='</s>')
	return koGPT2_vocab

def toString(list):
	if not list:
		return ''
	result = ''

	for i in list:
		result = result + i
	return result
